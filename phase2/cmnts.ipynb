# %%
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from time import sleep

MAX_COMMENTS = 100

browser = webdriver.Chrome('chromedriver.exe')
browser.get('https://www.instagram.com/accounts/login/')

sleep(4)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8520\119807585.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('chromedriver.exe')

# %%
usrname_txtbox = browser.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[1]/div/label/input')
usrname_txtbox.send_keys('miniproj6')
psswrd_txtbox = browser.find_element(By.XPATH, '//*[@id="loginForm"]/div/div[2]/div/label/input')
psswrd_txtbox.send_keys('AP@4012')
psswrd_txtbox.send_keys(Keys.ENTER)
sleep(6)

# %%
target_post = 'https://www.instagram.com/p/CsrAn4zIkCV/'
browser.get(target_post)
sleep(5)

# %%
cnt = 0

while cnt < MAX_COMMENTS:
    more_comments_btn = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/ul/li/div/button')
    if more_comments_btn:
        more_comments_btn[0].click()
    else:
        break
    cnt += 15
    sleep(2)

# %%
import pandas as pd
import re

# %%
def manipulate_comment(cmnt:list) -> pd.Series:
    print('arg:', cmnt)
    commenter = cmnt[0]
    cmnt.pop(0)
    likes = 0
    for exp in reversed(cmnt):
        if 'likesReply' in exp:
            likes = (re.findall(r"\d+", exp))[1]
    i = 0
    for exp in reversed(cmnt):
        if 'View replies' in exp:
            cmnt.remove(exp)
        if 'likesReply' in exp:
            cmnt.remove(exp)
        if 'See translation' in exp:
            cmnt.remove(exp)
        if i > 5:
            break
        i += 1
        
    return pd.Series({'NAME': commenter, 'COMMENT': '\n'.join(cmnt), 'LIKES': likes})

# %%
cmnts_ls = []

for i in range(MAX_COMMENTS):
#     try:
        cmnt = browser.find_element(By.XPATH, f'/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div/ul/ul[{i + 1}]')
        cmnt = cmnt.text.split('\n')
        print("__________________________")
#         print(manipulate_comment(cmnt), '^^^^^^^^^^^^^^^^')
        cmnts_ls.append(manipulate_comment(cmnt))
#     except:
#         print('kirekhar')
#         pass
# Out:
# __________________________
# arg: ['miniproj6', 'you', 'are', 'the', 'BEST', '23hReply']
# __________________________
# arg: ['stefano.gubert.33', 'Ronaldo my Dream Is iff you come too visit my mother whith Dybala shee dont have legs. hear in Italy treviso and have 87 years old', '2d5 likesReply']
# __________________________
# arg: ['yolinda965', '2d7 likesReply']
# __________________________
# arg: ['azddin_el_mafoud', '❤️❤️😍😍', '16h5 likesReply']
# __________________________
# arg: ['youcmah', '2d40 likesReply']
# __________________________
# arg: ['aymnally', 'رَبَّنَا آتِنَا فِي الدُّنْيَا حَسَنَةً وَفِي الآخِرَةِ حَسَنَةً وَقِنَا عَذَابَ النَّارِ". [البقرة - 201].', '18h11 likesReply', 'See translation']
# __________________________
# arg: ['balochessa881', 'ALWAYS SUIIIII🔥', '2d20 likesReply', 'View replies (6)']
# __________________________
# arg: ['marrastonina', '2d4 likesReply']
# __________________________
# arg: ['dylanabt13_', 'Célébration dormir ❤️', '1d10 likesReply', 'See translation']
# __________________________
# arg: ['veronikaoborna', '1d4 likesReply']
# __________________________
# arg: ['poet.florakazan', '❤️', '3d5 likesReply']
# __________________________
# arg: ['luca_giovannii', '1d4 likesReply']
# __________________________
# arg: ['alamin.sk.963', 'Assalamu alaikum bosss', '2d6 likesReply']
# __________________________
# arg: ['nasern0500', '1d3 likesReply']
# __________________________
# arg: ['momadoulowe', '1d7 likesReply']
# __________________________
# arg: ['xamir22x', 'The king ❤️', '2d4 likesReply']
# __________________________
# arg: ['timo_hm25', 'Bayern munich', '17h6 likesReply']
# __________________________
# arg: ['steve.world5', 'Just you cris', '1d3 likesReply']
# __________________________
# arg: ['ayad_shakr_harki', 'ئەم حەرەکەیە کون بووە 😂', '1d11 likesReply', 'See translation']
# __________________________
# arg: ['raydanhomemade', 'Which is my favourite? Is you. Since queen park rangers!', '2d4 likesReply']
# __________________________
# arg: ['k.abdulov7', '17h11 likesReply']
# __________________________
# arg: ['ademtahatemel01', '1d6 likesReply']
# __________________________
# arg: ['yolinda965', 'Suuuuuuuiiiiiiiiii ❤️❤️❤️🔥', '2d3 likesReply']
# __________________________
# arg: ['rameshchavan008', '🔥🔥🔥', '18h7 likesReply']
# __________________________
# arg: ['moammar.alzeydi', 'انت الاجمل الذي لن يتكرر على مر التاريخ كم انت رائع ياملك واسطورة الملاعب', '1d14 likesReply', 'See translation']
# __________________________
# arg: ['henrique_legey', 'GO TO BAYERN', '2d10 likesReply']
# __________________________
# arg: ['zafar80rpm', '🔥🔥🔥', '2d19 likesReply']
# __________________________
# arg: ['amadeuskleventdizdari', 'Hello, l am a mother from Albania. My son play football and is your big fans. He turns 10 years old, and he will be the happiest kids in the world, if you send a video message wishing him happy birthday. Maybe this message is not coming to you, but l wont to try for my boy Amadeus. Thank you, wish all the best for your family🙏🏻', '1d4 likesReply']
# __________________________
# arg: ['enims_joan', '2', '2d3 likesReply']
# __________________________
# arg: ['_sinan_xha_04', 'safwan', '22h6 likesReply', 'See translation']
# __________________________
# arg: ['phonk_3dnan', '2d27 likesReply']
# __________________________
# arg: ['nabil.ashraf7', 'The legend of the history ❤️🔥', '1d12 likesReply']
# __________________________
# arg: ['le_pacha_chichi', '@cristiano Hola mi idolo Christiano Ronaldo, soy tu fan desde pequeño y hoy cumplo 27 años. Mas de 10 años que te apoyo, se que seria milagroso que veas mi mensaje pero si el firmante me lo hace gracias CR7 solo necesito tu JERSEY firmada Charles Capo-Chichi para poder mostrarles a mis futuros hijos cuando les contare tu inspiradora historia.', '1d3 likesReply', 'See translation']
# __________________________
# arg: ['ayeshafrinakter', 'InshaALLAH one day you will take shahada.ameen❤️', '23h10 likesReply']
# __________________________
# arg: ['oth__mane_99', 'Suuuiii and calma', '1d11 likesReply']
# __________________________
# arg: ['valromanelli', '🤩🤩🤩🔥🔥🔥👏👏👏! The 1s .. Wouuuuuuu', '3d3 likesReply']
# __________________________
# arg: ['stendyokuliar', 'man why did you turn off the message function I cant write you happy birthday for your 39th😥', '1d4 likesReply']
# __________________________
# arg: ['eleni_cr7', '❤️❤️❤️', '3d3 likesReply']
# __________________________
# arg: ['_sinan_xha_04', 'lam indian pls reply ronaldo suuuiii', '22h6 likesReply', 'See translation']
# __________________________
# arg: ['shabid_hameed', 'Suiiii🔥❤️', '18h8 likesReply']
# __________________________
# arg: ['lydia_linda_pagianidou', 'The fist is the favourite of my son 😍', '2d3 likesReply']
# __________________________
# arg: ['shaikh_mohin_09', '1d11 likesReply']
# __________________________
# arg: ['youngfavouriteralte__ofs', 'Suiiiiiiii✌️', '2d19 likesReply']
# __________________________
# arg: ['jesushugo45', '🔥', '1d3 likesReply']
# __________________________
# arg: ['sonnie_oji', 'The G.O.A.T', '2d9 likesReply', 'View replies (10)']
# __________________________
# arg: ['cryonjan773355', 'My idol..true legend..😍😍😍', '1d3 likesReply']
# __________________________
# arg: ['ohnmarthw', 'idol', '18h5 likesReply']
# __________________________
# arg: ['adt0410', 'Messi❤️❤️❤️', '1d21 likesReply']
# __________________________
# arg: ['mors_lisonia', 'M’y love ❤️❤️❤️❤️❤️', '1d14 likesReply']
# __________________________
# arg: ['madinijote', 'All🔥🔥🔥🔥. SIUUU', '1d9 likesReply']
# __________________________
# arg: ['caprimansi', 'I love you ronaldo all of my friends support messi but I am the only one who likes you', '2d11 likesReply']
# __________________________
# arg: ['mad_solo_traveler', 'Suiiiií❤️❤️❤️', '1d6 likesReply']
# __________________________
# arg: ['the_blacky26', 'Todas 🔥🔥🔥pero en especial SIUUUUUUUUUU 😍😍😍😍😍😍😍😍', '1d3 likesReply', 'See translation']
# __________________________
# arg: ['jeeeesssie', '❤️🫠', '3d3 likesReply']
# __________________________
# arg: ['hermanazman', 'that oke goal u scored againts barca,u open your shirt and show it to the fans🔥🔥🔥', '2d12 likesReply']
# __________________________
# arg: ['naluri_alfadhil_11', 'Spirit i believe you can be star and shining the world with superstar than yesterday years years ago i pray with you Legend 🤍✨', '1d3 likesReply']
# __________________________
# arg: ['goncalogoncalves1st', 'Em Portugal criticam o Ronaldo mas em França ele é o Deus', '1d6 likesReply', 'See translation']
# __________________________
# arg: ['_ginpramudias', '❤️🔥Goat king siuuuuu', '1d8 likesReply']
# __________________________
# arg: ['agnelli.edoardo', 'Siuuuum', '2d12 likesReply']
# __________________________
# arg: ['jaxy_timba', 'Cr7🌟', '1d15 likesReply']
# __________________________
# arg: ['chef_himo', 'Calmz with suuuu', '2d16 likesReply']
# __________________________
# arg: ['androo_dodo', 'التذكير اليومي بأن رونالدو افضل لاعب في تاريخ كرة القدم 🐐❤Siuuuuuuuu ❤️🏆Ronaldo 🤍🖤', '⢠⣶⣾⣷⣦⡀⠀⣤⣤⣤⣤⣄⠀⣤⣤⣤⣤⣤⣤⣤ ⣾⣿⠁⢸⣿⣧⠀⣿⣿⠉⠹⣿⣆⠉⠉⠉⠉⣿⣿⠟ ⣿⣿⠀⠘⠛⠛⠀⣿⣿⠀⠀⣿⣿⠀⠀⠀⣼⣿⡟ ⢻⣿⣦⣼⣿⠏⠀⣿⣿⠀⢸⣿⣧⠀⢀⣿⣿ ⠈⠛⠛⠛⠋⠀⠀⠛⠛⠀⠀⠛⠛⠀⠸⠛⠛ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣦⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⣿⣿⠂⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⣿⣿⣀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⢠⣾⣿⣿⣿⣿⣿⣿⣦⠀ ⠀⠀⠀⠀⠀⠀⣴⣿⢿⣷⠒⠲⣾⣾⣿⣿ ⠀⠀⠀⠀⣴⣿⠟⠁⠀⢿⣿⠁⣿⣿⣿⠻⣿⣄⠀⠀⠀⠀ ⠀⠀⣠⡾⠟⠁⠀⠀⠀⢸⣿⣸⣿⣿⣿⣆⠙⢿⣷⡀⠀⠀ ⣰⡿⠋⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⠀⠀⠉⠻⣿⡀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⣿⣿⣿⣿⣿⣿⣆⠂⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⣼⣿⣿⣿⡿⣿⣿⣿⣿⡄⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⠿⠟⠀⠀⠻⣿⣿⡇⠀ ⠀⠀⠀⠀⠀⠀⢀⣾⡿⠃⠀⠀⠀⠀⠀⠘⢿⣿⡀⠀⠀⠀ ⠀⠀⠀⠀⠀⣰⣿⡟⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣷⡀⠀⠀ ⠀⠀⠀⠀⢠⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣿⣧⠀⠀ ⠀⠀⠀⢀⣿⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣿⣆⠀ ⠀⠀⠠⢾⠇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣷⡤⠄سي', '2d4 likesReply', 'See translation']
# __________________________
# arg: ['alexanderkues', 'Siuuuuuuu🔥🔥🔥🔥', '2d4 likesReply']
# __________________________
# arg: ['macharia7338', '👏', '1d7 likesReply']
# __________________________
# arg: ['mahmut_baran_yavuz', 'CRİSTİANO RONALDO CR7 AIRLINES SİUUU.GOAT.👏👏👏👏.', '22h9 likesReply']
# __________________________
# arg: ['santiagoortiz175', 'Siuuuuuuuuu.....', '1d5 likesReply']
# __________________________
# arg: ['04_ramazanli', 'Hello Ronaldo from Azerbaijan👋👋👋', '1d8 likesReply']
# __________________________
# arg: ['emmanueltomxy', 'Peace of mind', '2d7 likesReply']
# __________________________
# arg: ['cenkerche', 'You LEGEND.... ❤️🔥', '2d4 likesReply']
# __________________________
# arg: ['adam_auwal_justice', 'Sujood', '2d4 likesReply', 'See translation']
# __________________________
# arg: ['amar_1220_', '@me', '1d7 likesReply']
# __________________________
# arg: ['04_ramazanli', '1d7 likesReply']
# __________________________
# arg: ['emma_cool._', 'ＩLᵒᵛᵉᵧₒᵤ♥ cristiano', '2d4 likesReply', 'See translation']
# __________________________
# arg: ['alexis_campos181', 'Siiiiuuu🔥🔥', '2d13 likesReply']
# __________________________
# arg: ['amar_1220_', '@help', '1d5 likesReply']
# __________________________
# arg: ['amar_1220_', '@u', '1d11 likesReply']
# __________________________
# arg: ['amar_1220_', '@people', '1d6 likesReply']
# __________________________
# arg: ['nesssbyyy', 'Suuuuuuuu😭❤️', '2d4 likesReply']
# __________________________
# arg: ['wdshbwsh', '🙌', '1d6 likesReply']
# __________________________
# arg: ['slmbenethem', '2d157 likesReply']
# __________________________
# arg: ['diyar.nrs', 'Siuuuuuuuu', '1d6 likesReply']
# __________________________
# arg: ['amar_1220_', '@🙌', '1d7 likesReply']
# __________________________
# arg: ['hasanncagri', '1hReply']
# __________________________
# arg: ['alvarorodriguez654', 'Goat siuuu🔥🔥🔥', '1d8 likesReply']
# __________________________
# arg: ['ubaidhabib515', '⢠⣶⣾⣷⣦⡀⠀⣤⣤⣤⣤⣄⠀⣤⣤⣤⣤⣤⣤⣤', '⣾⣿⠁⢸⣿⣧⠀⣿⣿⠉⠹⣿⣆⠉⠉⠉⠉⣿⣿⠟', '⣿⣿⠀⠘⠛⠛⠀⣿⣿⠀⠀⣿⣿⠀⠀⠀⣼⣿⡟', '⣿⣿⠀⠀⠀⠀⠀⣿⣿⣤⣾⡿⠃⠀⠀⣼⣿⡟', '⣿⣿⠀⠀⠀⠀⠀⣿⣿⢻⣿⣇⠀⠀⠀⣿⣿⠁', '⣿⣿⠀⢸⣿⣷⠀⣿⣿⠀⣿⣿⡄⠀⠀⣿⣿', '⢻⣿⣦⣼⣿⠏⠀⣿⣿⠀⢸⣿⣧⠀⢀⣿⣿', '⠈⠛⠛⠛⠋⠀⠀⠛⠛⠀⠀⠛⠛⠀⠸⠛⠛', '⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣦⠀⠀⠀⠀⠀⠀⠀⠀', '⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⣿⣿⠂⠀⠀⠀⠀⠀⠀⠀⠀', '⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⣿⣿⣀⠀⠀⠀⠀⠀⠀⠀⠀', '⠀⠀⠀⠀⠀⠀⠀⢠⣾⣿⣿⣿⣿⣿⣿⣦⠀', '⠀⠀⠀⠀⠀⠀⣴⣿⢿⣷⠒⠲⣾⣾⣿⣿', '⠀⠀⠀⠀⣴⣿⠟⠁⠀⢿⣿⠁⣿⣿⣿⠻⣿⣄⠀⠀⠀⠀', '⠀⠀⣠⡾⠟⠁⠀⠀⠀⢸⣿⣸⣿⣿⣿⣆⠙⢿⣷⡀⠀⠀', '⣰⡿⠋⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⠀⠀⠉⠻⣿⡀', '⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⣿⣿⣿⣿⣿⣿⣆⠂⠀', '⠀⠀⠀⠀⠀⠀⠀⠀⣼⣿⣿⣿⡿⣿⣿⣿⣿⡄⠀⠀⠀⠀', '⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⠿⠟⠀⠀⠻⣿⣿⡇⠀⠀⠀⠀', '⠀⠀⠀⠀⠀⠀⢀⣾⡿⠃⠀⠀⠀⠀⠀⠘⢿⣿⡀⠀⠀⠀', '⠀⠀⠀⠀⠀⣰⣿⡟⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣷⡀⠀⠀', '⠀⠀⠀⠀⢠⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣿⣧⠀⠀', '⠀⠀⠀⢀⣿⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣿⣆⠀', '⠀⠀⠠⢾⠇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣷⡤⠄', '*SIIUUUUUUUUUUUUUUUUUUU*', '21h16 likesReply']
# __________________________
# arg: ['fw.trapyyz', '7', '22h5 likesReply']
# __________________________
# arg: ['magic_orange_', 'I am a famous person. After a thousand posts, I will tell you who I am🤐🍊🍊🍊', 'Who do you expect?🤐🍊🍊🍊', '1d8 likesReply']
# __________________________
# arg: ['shavesky_canadien', 'Monument, you will stay forever 🔥❤️', '1d4 likesReply']
# __________________________
# arg: ['17diegobarrera', 'Siiiiiu bicho 👽🛸💎', '1d5 likesReply']
# __________________________
# arg: ['amar_1220_', '@⊙\u2060﹏\u2060⊙', '1d6 likesReply']
# __________________________
# arg: ['tobias_hrlm', '1d59 likesReply']
# __________________________
# arg: ['thakur_aryawan', '⣾⣷⣦⡀⠀⣤⣤⣤⣤⣄⠀⣤⣤⣤⣤⣤⣤⣤ ⣾⣿⠁⢸⣿⣧⠀⣿⣿⠉⠹⣿⣆⠉⠉⠉⠉⣿⣿⠟ ⣿⣿⠀⠘⠛⠛⠀⣿⣿⠀⠀⣿⣿⠀⠀⠀⣼⣿⡟ ⣿⣿⠀⠀⠀⠀⠀⣿⣿⣤⣾⡿⠃⠀⠀⣼⣿⡟ ⣿⣿⠀⠀⠀⠀⠀⣿⣿⢻⣿⣇⠀⠀⠀⣿⣿⠁ ⣿⣿⠀⢸⣿⣷⠀⣿⣿⠀⣿⣿⡄⠀⠀⣿⣿ ⢻⣿⣦⣼⣿⠏⠀⣿⣿⠀⢸⣿⣧⠀⢀⣿⣿ ⠈⠛⠛⠛⠋⠀⠀⠛⠛⠀⠀⠛⠛⠀⠸⠛⠛ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣦⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⣿⣿⠂⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⣿⣿⣀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⢠⣾⣿⣿⣿⣿⣿⣿⣦⠀ ⠀⠀⠀⠀⠀⠀⣴⣿⢿⣷⠒⠲⣾⣾⣿⣿ ⠀⠀⠀⠀⣴⣿⠟⠁⠀⢿⣿⠁⣿⣿⣿⠻⣿⣄⠀⠀⠀⠀ ⠀⠀⣠⡾⠟⠁⠀⠀⠀⢸⣿⣸⣿⣿⣿⣆⠙⢿⣷⡀⠀⠀ ⣰⡿⠋⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⠀⠀⠉⠻⣿⡀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⣿⣿⣿⣿⣿⣿⣆⠂⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⣼⣿⣿⣿⡿⣿⣿⣿⣿⡄⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⠿⠟⠀⠀⠻⣿⣿⡇⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⢀⣾⡿⠃⠀⠀⠀⠀⠀⠘⢿⣿⡀⠀⠀⠀ ⠀⠀⠀⠀⠀⣰⣿⡟⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣷⡀⠀⠀ ⠀⠀⠀⠀⢠⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣿⣧⠀⠀ ⠀⠀⠀⢀⣿⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣿⣆⠀ ⠀⠀⠠⢾⠇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣷⡤⠄ *SİUUUUUUUUUUU*', '1d4 likesReply']
# __________________________
# arg: ['bz_mohamedali.officiel', 'https://youtube.com/@bz.mohamedali', '1d4 likesReply']
# __________________________
# arg: ['smiling_sapna_', 'ᴏꜰᴄᴏᴜʀꜱᴇ ᴛʜᴇ ꜱʟɪᴅᴇ ❤️', '3d22 likesReply']
# __________________________
# arg: ['msmr_94', 'Siuuuuuuuu ❤️🏆💓', '⢠⣶⣾⣷⣦⡀⠀⣤⣤⣤⣤⣄⠀⣤⣤⣤⣤⣤⣤⣤ ⣾⣿⠁⢸⣿⣧⠀⣿⣿⠉⠹⣿⣆⠉⠉⠉⠉⣿⣿⠟ ⣿⣿⠀⠘⠛⠛⠀⣿⣿⠀⠀⣿⣿⠀⠀⠀⣼⣿⡟ ⣿⣿⠀⠀⠀⠀⠀⣿⣿⣤⣾⡿⠃⠀⠀⣼⣿⡟ ⣿⣿⠀⠀⠀⠀⠀⣿⣿⢻⣿⣇⠀⠀⠀⣿⣿⠁ ⣿⣿⠀⢸⣿⣷⠀⣿⣿⠀⣿⣿⡄⠀⠀⣿⣿ ⢻⣿⣦⣼⣿⠏⠀⣿⣿⠀⢸⣿⣧⠀⢀⣿⣿ ⠈⠛⠛⠛⠋⠀⠀⠛⠛⠀⠀⠛⠛⠀⠸⠛⠛ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣦⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⣿⣿⠂⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⣿⣿⣀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⢠⣾⣿⣿⣿⣿⣿⣿⣦⠀ ⠀⠀⠀⠀⠀⠀⣴⣿⢿⣷⠒⠲⣾⣾⣿⣿ ⠀⠀⠀⠀⣴⣿⠟⠁⠀⢿⣿⠁⣿⣿⣿⠻⣿⣄⠀⠀⠀⠀ ⠀⠀⣠⡾⠟⠁⠀⠀⠀⢸⣿⣸⣿⣿⣿⣆⠙⢿⣷⡀⠀⠀ ⣰⡿⠋⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⠀⠀⠉⠻⣿⡀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⣿⣿⣿⣿⣿⣿⣆⠂⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⣼⣿⣿⣿⡿⣿⣿⣿⣿⡄⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⠿⠟⠀⠀⠻⣿⣿⡇⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⢀⣾⡿⠃⠀⠀⠀⠀⠀⠘⢿⣿⡀⠀⠀⠀ ⠀⠀⠀⠀⠀⣰⣿⡟⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣷⡀⠀⠀ ⠀⠀⠀⠀⢠⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣿⣧⠀⠀ ⠀⠀⠀⢀⣿⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣿⣆⠀ ⠀⠀⠠⢾⠇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣷⡤⠄. GOAT ❤️❤️', '1d14 likesReply']
# __________________________
# arg: ['nazimhrb', '⢠⣶⣾⣷⣦⡀⠀⣤⣤⣤⣤⣄⠀⣤⣤⣤⣤⣤⣤⣤ ⣾⣿⠁⢸⣿⣧⠀⣿⣿⠉⠹⣿⣆⠉⠉⠉⠉⣿⣿⠟ ⣿⣿⠀⠘⠛⠛⠀⣿⣿⠀⠀⣿⣿⠀⠀⠀⣼⣿⡟ ⣿⣿⠀⠀⠀⠀⠀⣿⣿⣤⣾⡿⠃⠀⠀⣼⣿⡟ ⣿⣿⠀⠀⠀⠀⠀⣿⣿⢻⣿⣇⠀⠀⠀⣿⣿⠁ ⣿⣿⠀⢸⣿⣷⠀⣿⣿⠀⣿⣿⡄⠀⠀⣿⣿ ⢻⣿⣦⣼⣿⠏⠀⣿⣿⠀⢸⣿⣧⠀⢀⣿⣿ ⠈⠛⠛⠛⠋⠀⠀⠛⠛⠀⠀⠛⠛⠀⠸⠛⠛ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣦⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⣿⣿⠂⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⣿⣿⣀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⢠⣾⣿⣿⣿⣿⣿⣿⣦⠀ ⠀⠀⠀⠀⠀⠀⣴⣿⢿⣷⠒⠲⣾⣾⣿⣿ ⠀⠀⠀⠀⣴⣿⠟⠁⠀⢿⣿⠁⣿⣿⣿⠻⣿⣄⠀⠀⠀⠀ ⠀⠀⣠⡾⠟⠁⠀⠀⠀⢸⣿⣸⣿⣿⣿⣆⠙⢿⣷⡀⠀⠀ ⣰⡿⠋⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⠀⠀⠉⠻⣿⡀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⣿⣿⣿⣿⣿⣿⣆⠂⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⣼⣿⣿⣿⡿⣿⣿⣿⣿⡄⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⠿⠟⠀⠀⠻⣿⣿⡇⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⢀⣾⡿⠃⠀⠀⠀⠀⠀⠘⢿⣿⡀⠀⠀⠀ ⠀⠀⠀⠀⠀⣰⣿⡟⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣷⡀⠀⠀ ⠀⠀⠀⠀⢠⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣿⣧⠀⠀ ⠀⠀⠀⢀⣿⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣿⣆⠀ ⠀⠀⠠⢾⠇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣷⡤⠄', '1d3 likesReply']
# __________________________
# arg: ['hoheidnf', '@masa_668_ انا جو شيلي البلوك بدي احكي معك', '1d7 likesReply', 'See translation']
# __________________________
# arg: ['ali_belhaj__', '⢠⣶⣾⣷⣦⡀⠀⣤⣤⣤⣤⣄⠀⣤⣤⣤⣤⣤⣤⣤ ⣾⣿⠁⢸⣿⣧⠀⣿⣿⠉⠹⣿⣆⠉⠉⠉⠉⣿⣿⠟ ⣿⣿⠀⠘⠛⠛⠀⣿⣿⠀⠀⣿⣿⠀⠀⠀⣼⣿⡟ ⣿⣿⠀⠀⠀⠀⠀⣿⣿⣤⣾⡿⠃⠀⠀⣼⣿⡟ ⣿⣿⠀⠀⠀⠀⠀⣿⣿⢻⣿⣇⠀⠀⠀⣿⣿⠁ ⣿⣿⠀⢸⣿⣷⠀⣿⣿⠀⣿⣿⡄⠀⠀⣿⣿ ⢻⣿⣦⣼⣿⠏⠀⣿⣿⠀⢸⣿⣧⠀⢀⣿⣿ ⠈⠛⠛⠛⠋⠀⠀⠛⠛⠀⠀⠛⠛⠀⠸⠛⠛ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣦⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⣿⣿⠂⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⣿⣿⣀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⢠⣾⣿⣿⣿⣿⣿⣿⣦⠀ ⠀⠀⠀⠀⠀⠀⣴⣿⢿⣷⠒⠲⣾⣾⣿⣿ ⠀⠀⠀⠀⣴⣿⠟⠁⠀⢿⣿⠁⣿⣿⣿⠻⣿⣄⠀⠀⠀⠀ ⠀⠀⣠⡾⠟⠁⠀⠀⠀⢸⣿⣸⣿⣿⣿⣆⠙⢿⣷⡀⠀⠀ ⣰⡿⠋⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⠀⠀⠉⠻⣿⡀ ⠀⠀⠀⣿⣿⣿⣿⣿⣿⣆⠂⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⣼⣿⣿⣿⡿⣿⣿⣿⣿⡄⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⠿⠟⠀⠀⠻⣿⣿⡇⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⢀⣾⡿⠃⠀⠀⠀⠀⠀⠘⢿⣿⡀⠀⠀⠀ ⠀⠀⠀⠀⠀⣰⣿⡟⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣷⡀⠀⠀ ⠀⠀⠀⠀⢠⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣿⣧⠀⠀ ⠀⠀⠀⢀⣿⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣿⣆⠀ ⠀⠀⠠⢾⠇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣷⡤⠄', '1d25 likesReply']
# __________________________
# arg: ['_ginpramudias', '❤️🔥Goat king siiiiiii', '1d4 likesReply', 'See translation']
# __________________________
# arg: ['ayaka15_4', '🔥🔥🔥🔥🔥', '1d6 likesReply']

# %%
len(cmnts_ls)    # so we got commenters name correctly
# Out:
# 100

# %%
df = pd.DataFrame(cmnts_ls)

# %%
df.tail(10)
# Out:
#                       NAME                                            COMMENT
# 90             tobias_hrlm                                                     \
# 91          thakur_aryawan  ⣾⣷⣦⡀⠀⣤⣤⣤⣤⣄⠀⣤⣤⣤⣤⣤⣤⣤ ⣾⣿⠁⢸⣿⣧⠀⣿⣿⠉⠹⣿⣆⠉⠉⠉⠉⣿⣿⠟ ⣿⣿⠀⠘⠛⠛...
# 92  bz_mohamedali.officiel                 https://youtube.com/@bz.mohamedali
# 93          smiling_sapna_                              ᴏꜰᴄᴏᴜʀꜱᴇ ᴛʜᴇ ꜱʟɪᴅᴇ ❤️
# 94                 msmr_94  Siuuuuuuuu ❤️🏆💓\n⢠⣶⣾⣷⣦⡀⠀⣤⣤⣤⣤⣄⠀⣤⣤⣤⣤⣤⣤⣤ ⣾⣿⠁⢸⣿⣧⠀⣿...
# 95                nazimhrb  ⢠⣶⣾⣷⣦⡀⠀⣤⣤⣤⣤⣄⠀⣤⣤⣤⣤⣤⣤⣤ ⣾⣿⠁⢸⣿⣧⠀⣿⣿⠉⠹⣿⣆⠉⠉⠉⠉⣿⣿⠟ ⣿⣿⠀⠘...
# 96                hoheidnf         @masa_668_ انا جو شيلي البلوك بدي احكي معك
# 97            ali_belhaj__  ⢠⣶⣾⣷⣦⡀⠀⣤⣤⣤⣤⣄⠀⣤⣤⣤⣤⣤⣤⣤ ⣾⣿⠁⢸⣿⣧⠀⣿⣿⠉⠹⣿⣆⠉⠉⠉⠉⣿⣿⠟ ⣿⣿⠀⠘...
# 98           _ginpramudias                              ❤️🔥Goat king siiiiiii
# 99               ayaka15_4                                              🔥🔥🔥🔥🔥
#
#    LIKES
# 90    59
# 91     4
# 92     4
# 93    22
# 94    14
# 95     3
# 96     7
# 97    25
# 98     4
# 99     6

# %%
df.to_csv('output.csv', index=False)
